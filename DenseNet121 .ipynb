# %% [markdown]
# # Setup Colab

# %%
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,Concatenate,GlobalAveragePooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
#from resnets_utils import *
from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py:434: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '

# %% [markdown]
# # Connect My Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### DenseNet121 Implementation

# %%
from keras.engine import Layer, InputSpec
try:
    from keras import initializations
except ImportError:
    from keras import initializers as initializations
import keras.backend as K

class Scale(Layer):
    '''Custom Layer for DenseNet used for BatchNormalization.
    
    Learns a set of weights and biases used for scaling the input data.
    the output consists simply in an element-wise multiplication of the input
    and a sum of a set of constants:
        out = in * gamma + beta,
    where 'gamma' and 'beta' are the weights and biases larned.
    # Arguments
        axis: integer, axis along which to normalize in mode 0. For instance,
            if your input tensor has shape (samples, channels, rows, cols),
            set axis to 1 to normalize per feature map (channels axis).
        momentum: momentum in the computation of the
            exponential average of the mean and standard deviation
            of the data, for feature-wise normalization.
        weights: Initialization weights.
            List of 2 Numpy arrays, with shapes:
            `[(input_shape,), (input_shape,)]`
        beta_init: name of initialization function for shift parameter
            (see [initializations](../initializations.md)), or alternatively,
            Theano/TensorFlow function to use for weights initialization.
            This parameter is only relevant if you don't pass a `weights` argument.
        gamma_init: name of initialization function for scale parameter (see
            [initializations](../initializations.md)), or alternatively,
            Theano/TensorFlow function to use for weights initialization.
            This parameter is only relevant if you don't pass a `weights` argument.
    '''
    def __init__(self, weights=None, axis=-1, momentum = 0.9, beta_init='zero', gamma_init='one', **kwargs):
        self.momentum = momentum
        self.axis = axis
        self.beta_init = initializations.get(beta_init)
        self.gamma_init = initializations.get(gamma_init)
        self.initial_weights = weights
        super(Scale, self).__init__(**kwargs)

    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        shape = (int(input_shape[self.axis]),)

        # Tensorflow >= 1.0.0 compatibility
        self.gamma = K.variable(self.gamma_init(shape), name='{}_gamma'.format(self.name))
        self.beta = K.variable(self.beta_init(shape), name='{}_beta'.format(self.name))
        #self.gamma = self.gamma_init(shape, name='{}_gamma'.format(self.name))
        #self.beta = self.beta_init(shape, name='{}_beta'.format(self.name))
        self._trainable_weights = [self.gamma, self.beta]

        if self.initial_weights is not None:
            self.set_weights(self.initial_weights)
            del self.initial_weights

    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        broadcast_shape = [1] * len(input_shape)
        broadcast_shape[self.axis] = input_shape[self.axis]

        out = K.reshape(self.gamma, broadcast_shape) * x + K.reshape(self.beta, broadcast_shape)
        return out

    def get_config(self):
        config = {"momentum": self.momentum, "axis": self.axis}
        base_config = super(Scale, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
def conv_block(x, stage, branch, nb_filter, dropout_rate=None, weight_decay=1e-4):
    '''Apply BatchNorm, Relu, bottleneck 1x1 Conv2D, 3x3 Conv2D, and option dropout
        # Arguments
            x: input tensor 
            stage: index for dense block
            branch: layer index within each dense block
            nb_filter: number of filters
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    '''
    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_' + str(branch)
    relu_name_base = 'relu' + str(stage) + '_' + str(branch)

    # 1x1 Convolution (Bottleneck layer)
    inter_channel = nb_filter * 4  
    x = BatchNormalization(epsilon=eps, axis=3, name=conv_name_base+'_x1_bn')(x)
    x = Scale(axis=3, name=conv_name_base+'_x1_scale')(x)
    x = Activation('relu', name=relu_name_base+'_x1')(x)
    x = Conv2D(inter_channel, 1, 1, name=conv_name_base+'_x1', padding= 'same' ,use_bias=False)(x)
    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    # 3x3 Convolution
    x = BatchNormalization(epsilon=eps, axis=3, name=conv_name_base+'_x2_bn')(x)
    x = Scale(axis=3, name=conv_name_base+'_x2_scale')(x)
    x = Activation('relu', name=relu_name_base+'_x2')(x)
    #x = ZeroPadding2D((1, 1), name=conv_name_base+'_x2_zeropadding')(x)
    x = Conv2D(nb_filter, (3, 3), name=conv_name_base+'_x2', padding = 'same', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x

# %% [markdown]
# #transition block

# %%
def transition_block(x, stage, nb_filter, compression=1.0, dropout_rate=None, weight_decay=1E-4):
    ''' Apply BatchNorm, 1x1 Convolution, averagePooling, optional compression, dropout 
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_filter: number of filters
            compression: calculated as 1 - reduction. Reduces the number of feature maps in the transition block.
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    '''

    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_blk'
    relu_name_base = 'relu' + str(stage) + '_blk'
    pool_name_base = 'pool' + str(stage) 

    x = BatchNormalization(epsilon=eps, axis=3, name=conv_name_base+'_bn')(x)
    x = Scale(axis=3, name=conv_name_base+'_scale')(x)
    x = Activation('relu', name=relu_name_base)(x)
    x = Conv2D(int(nb_filter * compression), 1, 1, name=conv_name_base, use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    x = AveragePooling2D((2, 2), strides=(2, 2), name=pool_name_base)(x)

    return x

# %%
def dense_block(x, stage, nb_layers, nb_filter, growth_rate, dropout_rate=None, weight_decay=1e-4, grow_nb_filters=True):
    ''' Build a dense_block where the output of each conv_block is fed to subsequent ones
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_layers: the number of layers of conv_block to append to the model.
            nb_filter: number of filters
            growth_rate: growth rate
            dropout_rate: dropout rate
            weight_decay: weight decay factor
            grow_nb_filters: flag to decide to allow number of filters to grow
    '''

    eps = 1.1e-5
    concat_feat = x
    
    for i in range(nb_layers):
        branch = i+1
        x = conv_block(concat_feat, stage, branch, growth_rate, dropout_rate, weight_decay)
        concat_feat = Concatenate (axis=-1)([concat_feat, x])

        if grow_nb_filters:
            nb_filter += growth_rate

    return concat_feat, nb_filter

# %%
print( K.image_data_format())
# Out:
# channels_last

# %%
def DenseNet(nb_dense_block=4, growth_rate=32, nb_filter=64, reduction=0.0, dropout_rate=0.0, weight_decay=1e-4, classes=1000, weights_path=None):
    '''Instantiate the DenseNet 121 architecture,
        # Arguments
            nb_dense_block: number of dense blocks to add to end
            growth_rate: number of filters to add per dense block
            nb_filter: initial number of filters
            reduction: reduction factor of transition blocks.
            dropout_rate: dropout rate
            weight_decay: weight decay factor
            classes: optional number of classes to classify images
            weights_path: path to pre-trained weights
        # Returns
            A Keras model instance.
    '''
    eps = 1.1e-5
    
    # compute compression factor
    compression = 1.0 - reduction
    
    img_input = Input(shape=(224, 224, 3), name='data')
    concat_axis = 3
    nb_filter = 64
    nb_layers = [6,12,24,16] # For DenseNet-121

    # Initial convolution
    x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(img_input)
    x = Conv2D(nb_filter, (7, 7), strides=(2, 2), name='conv1', use_bias=False)(x)
    x = BatchNormalization(epsilon=eps, axis = 3, name='conv1_bn')(x)
    x = Scale(axis=3, name='conv1_scale')(x)
    x = Activation('relu', name='relu1')(x)
    x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)

    # Add dense blocks
    for block_idx in range(nb_dense_block - 1):
        stage = block_idx+2
        x, nb_filter = dense_block(x, stage, nb_layers[block_idx], nb_filter, growth_rate, dropout_rate=dropout_rate, weight_decay=weight_decay)

        # Add transition_block
        x = transition_block(x, stage, nb_filter, compression=compression, dropout_rate=dropout_rate, weight_decay=weight_decay)
        nb_filter = int(nb_filter * compression)

    final_stage = stage + 1
    x, nb_filter = dense_block(x, final_stage, nb_layers[-1], nb_filter, growth_rate, dropout_rate=dropout_rate, weight_decay=weight_decay)

    x = BatchNormalization(epsilon=eps, axis=3, name='conv'+str(final_stage)+'_blk_bn')(x)
    x = Scale(axis=3, name='conv'+str(final_stage)+'_blk_scale')(x)
    x = Activation('relu', name='relu'+str(final_stage)+'_blk')(x)
    x = GlobalAveragePooling2D(name='pool'+str(final_stage))(x)

    x = Dense(classes, name='fc6')(x)
    x = Activation('softmax', name='prob')(x)

    model = Model(img_input, x)
    model.summary()

    if weights_path is not None:
      model.load_weights(weights_path)

    return model

# %%
modleldense=DenseNet()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_zeropadding (ZeroPadding2 (None, 230, 230, 3)  0           data[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9408        conv1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_scale (Scale)             (None, 112, 112, 64) 128         conv1_bn[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 112, 112, 64) 0           conv1_scale[0][0]
# __________________________________________________________________________________________________
# pool1_zeropadding (ZeroPadding2 (None, 114, 114, 64) 0           relu1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           pool1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1_bn (BatchNormalizati (None, 56, 56, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1_scale (Scale)        (None, 56, 56, 64)   128         conv2_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_1_x1 (Activation)         (None, 56, 56, 64)   0           conv2_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1 (Conv2D)             (None, 56, 56, 128)  8192        relu2_1_x1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_bn (BatchNormalizati (None, 56, 56, 128)  512         conv2_1_x1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_scale (Scale)        (None, 56, 56, 128)  256         conv2_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_1_x2 (Activation)         (None, 56, 56, 128)  0           conv2_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2 (Conv2D)             (None, 56, 56, 32)   36864       relu2_1_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_116 (Concatenate)   (None, 56, 56, 96)   0           pool1[0][0]
#                                                                  conv2_1_x2[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1_bn (BatchNormalizati (None, 56, 56, 96)   384         concatenate_116[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1_scale (Scale)        (None, 56, 56, 96)   192         conv2_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_2_x1 (Activation)         (None, 56, 56, 96)   0           conv2_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1 (Conv2D)             (None, 56, 56, 128)  12288       relu2_2_x1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_bn (BatchNormalizati (None, 56, 56, 128)  512         conv2_2_x1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_scale (Scale)        (None, 56, 56, 128)  256         conv2_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_2_x2 (Activation)         (None, 56, 56, 128)  0           conv2_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2 (Conv2D)             (None, 56, 56, 32)   36864       relu2_2_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_117 (Concatenate)   (None, 56, 56, 128)  0           concatenate_116[0][0]
#                                                                  conv2_2_x2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1_bn (BatchNormalizati (None, 56, 56, 128)  512         concatenate_117[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1_scale (Scale)        (None, 56, 56, 128)  256         conv2_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_3_x1 (Activation)         (None, 56, 56, 128)  0           conv2_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1 (Conv2D)             (None, 56, 56, 128)  16384       relu2_3_x1[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_bn (BatchNormalizati (None, 56, 56, 128)  512         conv2_3_x1[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_scale (Scale)        (None, 56, 56, 128)  256         conv2_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_3_x2 (Activation)         (None, 56, 56, 128)  0           conv2_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2 (Conv2D)             (None, 56, 56, 32)   36864       relu2_3_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_118 (Concatenate)   (None, 56, 56, 160)  0           concatenate_117[0][0]
#                                                                  conv2_3_x2[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1_bn (BatchNormalizati (None, 56, 56, 160)  640         concatenate_118[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1_scale (Scale)        (None, 56, 56, 160)  320         conv2_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_4_x1 (Activation)         (None, 56, 56, 160)  0           conv2_4_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1 (Conv2D)             (None, 56, 56, 128)  20480       relu2_4_x1[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_bn (BatchNormalizati (None, 56, 56, 128)  512         conv2_4_x1[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_scale (Scale)        (None, 56, 56, 128)  256         conv2_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_4_x2 (Activation)         (None, 56, 56, 128)  0           conv2_4_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2 (Conv2D)             (None, 56, 56, 32)   36864       relu2_4_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_119 (Concatenate)   (None, 56, 56, 192)  0           concatenate_118[0][0]
#                                                                  conv2_4_x2[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1_bn (BatchNormalizati (None, 56, 56, 192)  768         concatenate_119[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1_scale (Scale)        (None, 56, 56, 192)  384         conv2_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_5_x1 (Activation)         (None, 56, 56, 192)  0           conv2_5_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1 (Conv2D)             (None, 56, 56, 128)  24576       relu2_5_x1[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_bn (BatchNormalizati (None, 56, 56, 128)  512         conv2_5_x1[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_scale (Scale)        (None, 56, 56, 128)  256         conv2_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_5_x2 (Activation)         (None, 56, 56, 128)  0           conv2_5_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2 (Conv2D)             (None, 56, 56, 32)   36864       relu2_5_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_120 (Concatenate)   (None, 56, 56, 224)  0           concatenate_119[0][0]
#                                                                  conv2_5_x2[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1_bn (BatchNormalizati (None, 56, 56, 224)  896         concatenate_120[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1_scale (Scale)        (None, 56, 56, 224)  448         conv2_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_6_x1 (Activation)         (None, 56, 56, 224)  0           conv2_6_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1 (Conv2D)             (None, 56, 56, 128)  28672       relu2_6_x1[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_bn (BatchNormalizati (None, 56, 56, 128)  512         conv2_6_x1[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_scale (Scale)        (None, 56, 56, 128)  256         conv2_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_6_x2 (Activation)         (None, 56, 56, 128)  0           conv2_6_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2 (Conv2D)             (None, 56, 56, 32)   36864       relu2_6_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_121 (Concatenate)   (None, 56, 56, 256)  0           concatenate_120[0][0]
#                                                                  conv2_6_x2[0][0]
# __________________________________________________________________________________________________
# conv2_blk_bn (BatchNormalizatio (None, 56, 56, 256)  1024        concatenate_121[0][0]
# __________________________________________________________________________________________________
# conv2_blk_scale (Scale)         (None, 56, 56, 256)  512         conv2_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu2_blk (Activation)          (None, 56, 56, 256)  0           conv2_blk_scale[0][0]
# __________________________________________________________________________________________________
# conv2_blk (Conv2D)              (None, 56, 56, 256)  65536       relu2_blk[0][0]
# __________________________________________________________________________________________________
# pool2 (AveragePooling2D)        (None, 28, 28, 256)  0           conv2_blk[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1_bn (BatchNormalizati (None, 28, 28, 256)  1024        pool2[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1_scale (Scale)        (None, 28, 28, 256)  512         conv3_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_1_x1 (Activation)         (None, 28, 28, 256)  0           conv3_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1 (Conv2D)             (None, 28, 28, 128)  32768       relu3_1_x1[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_1_x1[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_scale (Scale)        (None, 28, 28, 128)  256         conv3_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_1_x2 (Activation)         (None, 28, 28, 128)  0           conv3_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2 (Conv2D)             (None, 28, 28, 32)   36864       relu3_1_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_122 (Concatenate)   (None, 28, 28, 288)  0           pool2[0][0]
#                                                                  conv3_1_x2[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1_bn (BatchNormalizati (None, 28, 28, 288)  1152        concatenate_122[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1_scale (Scale)        (None, 28, 28, 288)  576         conv3_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_2_x1 (Activation)         (None, 28, 28, 288)  0           conv3_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1 (Conv2D)             (None, 28, 28, 128)  36864       relu3_2_x1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_2_x1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_scale (Scale)        (None, 28, 28, 128)  256         conv3_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_2_x2 (Activation)         (None, 28, 28, 128)  0           conv3_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2 (Conv2D)             (None, 28, 28, 32)   36864       relu3_2_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_123 (Concatenate)   (None, 28, 28, 320)  0           concatenate_122[0][0]
#                                                                  conv3_2_x2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1_bn (BatchNormalizati (None, 28, 28, 320)  1280        concatenate_123[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1_scale (Scale)        (None, 28, 28, 320)  640         conv3_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_3_x1 (Activation)         (None, 28, 28, 320)  0           conv3_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1 (Conv2D)             (None, 28, 28, 128)  40960       relu3_3_x1[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_3_x1[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_scale (Scale)        (None, 28, 28, 128)  256         conv3_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_3_x2 (Activation)         (None, 28, 28, 128)  0           conv3_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2 (Conv2D)             (None, 28, 28, 32)   36864       relu3_3_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_124 (Concatenate)   (None, 28, 28, 352)  0           concatenate_123[0][0]
#                                                                  conv3_3_x2[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1_bn (BatchNormalizati (None, 28, 28, 352)  1408        concatenate_124[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1_scale (Scale)        (None, 28, 28, 352)  704         conv3_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_4_x1 (Activation)         (None, 28, 28, 352)  0           conv3_4_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1 (Conv2D)             (None, 28, 28, 128)  45056       relu3_4_x1[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_4_x1[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_scale (Scale)        (None, 28, 28, 128)  256         conv3_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_4_x2 (Activation)         (None, 28, 28, 128)  0           conv3_4_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2 (Conv2D)             (None, 28, 28, 32)   36864       relu3_4_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_125 (Concatenate)   (None, 28, 28, 384)  0           concatenate_124[0][0]
#                                                                  conv3_4_x2[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1_bn (BatchNormalizati (None, 28, 28, 384)  1536        concatenate_125[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1_scale (Scale)        (None, 28, 28, 384)  768         conv3_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_5_x1 (Activation)         (None, 28, 28, 384)  0           conv3_5_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1 (Conv2D)             (None, 28, 28, 128)  49152       relu3_5_x1[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_5_x1[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_scale (Scale)        (None, 28, 28, 128)  256         conv3_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_5_x2 (Activation)         (None, 28, 28, 128)  0           conv3_5_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2 (Conv2D)             (None, 28, 28, 32)   36864       relu3_5_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_126 (Concatenate)   (None, 28, 28, 416)  0           concatenate_125[0][0]
#                                                                  conv3_5_x2[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1_bn (BatchNormalizati (None, 28, 28, 416)  1664        concatenate_126[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1_scale (Scale)        (None, 28, 28, 416)  832         conv3_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_6_x1 (Activation)         (None, 28, 28, 416)  0           conv3_6_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1 (Conv2D)             (None, 28, 28, 128)  53248       relu3_6_x1[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_6_x1[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_scale (Scale)        (None, 28, 28, 128)  256         conv3_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_6_x2 (Activation)         (None, 28, 28, 128)  0           conv3_6_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2 (Conv2D)             (None, 28, 28, 32)   36864       relu3_6_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_127 (Concatenate)   (None, 28, 28, 448)  0           concatenate_126[0][0]
#                                                                  conv3_6_x2[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1_bn (BatchNormalizati (None, 28, 28, 448)  1792        concatenate_127[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1_scale (Scale)        (None, 28, 28, 448)  896         conv3_7_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_7_x1 (Activation)         (None, 28, 28, 448)  0           conv3_7_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1 (Conv2D)             (None, 28, 28, 128)  57344       relu3_7_x1[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_7_x1[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_scale (Scale)        (None, 28, 28, 128)  256         conv3_7_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_7_x2 (Activation)         (None, 28, 28, 128)  0           conv3_7_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2 (Conv2D)             (None, 28, 28, 32)   36864       relu3_7_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_128 (Concatenate)   (None, 28, 28, 480)  0           concatenate_127[0][0]
#                                                                  conv3_7_x2[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1_bn (BatchNormalizati (None, 28, 28, 480)  1920        concatenate_128[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1_scale (Scale)        (None, 28, 28, 480)  960         conv3_8_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_8_x1 (Activation)         (None, 28, 28, 480)  0           conv3_8_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1 (Conv2D)             (None, 28, 28, 128)  61440       relu3_8_x1[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_8_x1[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_scale (Scale)        (None, 28, 28, 128)  256         conv3_8_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_8_x2 (Activation)         (None, 28, 28, 128)  0           conv3_8_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2 (Conv2D)             (None, 28, 28, 32)   36864       relu3_8_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_129 (Concatenate)   (None, 28, 28, 512)  0           concatenate_128[0][0]
#                                                                  conv3_8_x2[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1_bn (BatchNormalizati (None, 28, 28, 512)  2048        concatenate_129[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1_scale (Scale)        (None, 28, 28, 512)  1024        conv3_9_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_9_x1 (Activation)         (None, 28, 28, 512)  0           conv3_9_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1 (Conv2D)             (None, 28, 28, 128)  65536       relu3_9_x1[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_9_x1[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_scale (Scale)        (None, 28, 28, 128)  256         conv3_9_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_9_x2 (Activation)         (None, 28, 28, 128)  0           conv3_9_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2 (Conv2D)             (None, 28, 28, 32)   36864       relu3_9_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_130 (Concatenate)   (None, 28, 28, 544)  0           concatenate_129[0][0]
#                                                                  conv3_9_x2[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1_bn (BatchNormalizat (None, 28, 28, 544)  2176        concatenate_130[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1_scale (Scale)       (None, 28, 28, 544)  1088        conv3_10_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_10_x1 (Activation)        (None, 28, 28, 544)  0           conv3_10_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1 (Conv2D)            (None, 28, 28, 128)  69632       relu3_10_x1[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_10_x1[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_scale (Scale)       (None, 28, 28, 128)  256         conv3_10_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_10_x2 (Activation)        (None, 28, 28, 128)  0           conv3_10_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2 (Conv2D)            (None, 28, 28, 32)   36864       relu3_10_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_131 (Concatenate)   (None, 28, 28, 576)  0           concatenate_130[0][0]
#                                                                  conv3_10_x2[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1_bn (BatchNormalizat (None, 28, 28, 576)  2304        concatenate_131[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1_scale (Scale)       (None, 28, 28, 576)  1152        conv3_11_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_11_x1 (Activation)        (None, 28, 28, 576)  0           conv3_11_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1 (Conv2D)            (None, 28, 28, 128)  73728       relu3_11_x1[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_11_x1[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_scale (Scale)       (None, 28, 28, 128)  256         conv3_11_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_11_x2 (Activation)        (None, 28, 28, 128)  0           conv3_11_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2 (Conv2D)            (None, 28, 28, 32)   36864       relu3_11_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_132 (Concatenate)   (None, 28, 28, 608)  0           concatenate_131[0][0]
#                                                                  conv3_11_x2[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1_bn (BatchNormalizat (None, 28, 28, 608)  2432        concatenate_132[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1_scale (Scale)       (None, 28, 28, 608)  1216        conv3_12_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_12_x1 (Activation)        (None, 28, 28, 608)  0           conv3_12_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1 (Conv2D)            (None, 28, 28, 128)  77824       relu3_12_x1[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_12_x1[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_scale (Scale)       (None, 28, 28, 128)  256         conv3_12_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_12_x2 (Activation)        (None, 28, 28, 128)  0           conv3_12_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2 (Conv2D)            (None, 28, 28, 32)   36864       relu3_12_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_133 (Concatenate)   (None, 28, 28, 640)  0           concatenate_132[0][0]
#                                                                  conv3_12_x2[0][0]
# __________________________________________________________________________________________________
# conv3_blk_bn (BatchNormalizatio (None, 28, 28, 640)  2560        concatenate_133[0][0]
# __________________________________________________________________________________________________
# conv3_blk_scale (Scale)         (None, 28, 28, 640)  1280        conv3_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu3_blk (Activation)          (None, 28, 28, 640)  0           conv3_blk_scale[0][0]
# __________________________________________________________________________________________________
# conv3_blk (Conv2D)              (None, 28, 28, 640)  409600      relu3_blk[0][0]
# __________________________________________________________________________________________________
# pool3 (AveragePooling2D)        (None, 14, 14, 640)  0           conv3_blk[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1_bn (BatchNormalizati (None, 14, 14, 640)  2560        pool3[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1_scale (Scale)        (None, 14, 14, 640)  1280        conv4_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_1_x1 (Activation)         (None, 14, 14, 640)  0           conv4_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1 (Conv2D)             (None, 14, 14, 128)  81920       relu4_1_x1[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_1_x1[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_scale (Scale)        (None, 14, 14, 128)  256         conv4_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_1_x2 (Activation)         (None, 14, 14, 128)  0           conv4_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2 (Conv2D)             (None, 14, 14, 32)   36864       relu4_1_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_134 (Concatenate)   (None, 14, 14, 672)  0           pool3[0][0]
#                                                                  conv4_1_x2[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1_bn (BatchNormalizati (None, 14, 14, 672)  2688        concatenate_134[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1_scale (Scale)        (None, 14, 14, 672)  1344        conv4_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_2_x1 (Activation)         (None, 14, 14, 672)  0           conv4_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1 (Conv2D)             (None, 14, 14, 128)  86016       relu4_2_x1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_2_x1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_scale (Scale)        (None, 14, 14, 128)  256         conv4_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_2_x2 (Activation)         (None, 14, 14, 128)  0           conv4_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2 (Conv2D)             (None, 14, 14, 32)   36864       relu4_2_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_135 (Concatenate)   (None, 14, 14, 704)  0           concatenate_134[0][0]
#                                                                  conv4_2_x2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1_bn (BatchNormalizati (None, 14, 14, 704)  2816        concatenate_135[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1_scale (Scale)        (None, 14, 14, 704)  1408        conv4_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_3_x1 (Activation)         (None, 14, 14, 704)  0           conv4_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1 (Conv2D)             (None, 14, 14, 128)  90112       relu4_3_x1[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_3_x1[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_scale (Scale)        (None, 14, 14, 128)  256         conv4_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_3_x2 (Activation)         (None, 14, 14, 128)  0           conv4_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2 (Conv2D)             (None, 14, 14, 32)   36864       relu4_3_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_136 (Concatenate)   (None, 14, 14, 736)  0           concatenate_135[0][0]
#                                                                  conv4_3_x2[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1_bn (BatchNormalizati (None, 14, 14, 736)  2944        concatenate_136[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1_scale (Scale)        (None, 14, 14, 736)  1472        conv4_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_4_x1 (Activation)         (None, 14, 14, 736)  0           conv4_4_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1 (Conv2D)             (None, 14, 14, 128)  94208       relu4_4_x1[0][0]
# __________________________________________________________________________________________________
# conv4_4_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_4_x1[0][0]
# __________________________________________________________________________________________________
# conv4_4_x2_scale (Scale)        (None, 14, 14, 128)  256         conv4_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_4_x2 (Activation)         (None, 14, 14, 128)  0           conv4_4_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_4_x2 (Conv2D)             (None, 14, 14, 32)   36864       relu4_4_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_137 (Concatenate)   (None, 14, 14, 768)  0           concatenate_136[0][0]
#                                                                  conv4_4_x2[0][0]
# __________________________________________________________________________________________________
# conv4_5_x1_bn (BatchNormalizati (None, 14, 14, 768)  3072        concatenate_137[0][0]
# __________________________________________________________________________________________________
# conv4_5_x1_scale (Scale)        (None, 14, 14, 768)  1536        conv4_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_5_x1 (Activation)         (None, 14, 14, 768)  0           conv4_5_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_5_x1 (Conv2D)             (None, 14, 14, 128)  98304       relu4_5_x1[0][0]
# __________________________________________________________________________________________________
# conv4_5_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_5_x1[0][0]
# __________________________________________________________________________________________________
# conv4_5_x2_scale (Scale)        (None, 14, 14, 128)  256         conv4_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_5_x2 (Activation)         (None, 14, 14, 128)  0           conv4_5_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_5_x2 (Conv2D)             (None, 14, 14, 32)   36864       relu4_5_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_138 (Concatenate)   (None, 14, 14, 800)  0           concatenate_137[0][0]
#                                                                  conv4_5_x2[0][0]
# __________________________________________________________________________________________________
# conv4_6_x1_bn (BatchNormalizati (None, 14, 14, 800)  3200        concatenate_138[0][0]
# __________________________________________________________________________________________________
# conv4_6_x1_scale (Scale)        (None, 14, 14, 800)  1600        conv4_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_6_x1 (Activation)         (None, 14, 14, 800)  0           conv4_6_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_6_x1 (Conv2D)             (None, 14, 14, 128)  102400      relu4_6_x1[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv5_9_x1 (Conv2D)             (None, 7, 7, 128)    212992      relu5_9_x1[0][0]
# __________________________________________________________________________________________________
# conv5_9_x2_bn (BatchNormalizati (None, 7, 7, 128)    512         conv5_9_x1[0][0]
# __________________________________________________________________________________________________
# conv5_9_x2_scale (Scale)        (None, 7, 7, 128)    256         conv5_9_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_9_x2 (Activation)         (None, 7, 7, 128)    0           conv5_9_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_9_x2 (Conv2D)             (None, 7, 7, 32)     36864       relu5_9_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_166 (Concatenate)   (None, 7, 7, 1696)   0           concatenate_165[0][0]
#                                                                  conv5_9_x2[0][0]
# __________________________________________________________________________________________________
# conv5_10_x1_bn (BatchNormalizat (None, 7, 7, 1696)   6784        concatenate_166[0][0]
# __________________________________________________________________________________________________
# conv5_10_x1_scale (Scale)       (None, 7, 7, 1696)   3392        conv5_10_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_10_x1 (Activation)        (None, 7, 7, 1696)   0           conv5_10_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_10_x1 (Conv2D)            (None, 7, 7, 128)    217088      relu5_10_x1[0][0]
# __________________________________________________________________________________________________
# conv5_10_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_10_x1[0][0]
# __________________________________________________________________________________________________
# conv5_10_x2_scale (Scale)       (None, 7, 7, 128)    256         conv5_10_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_10_x2 (Activation)        (None, 7, 7, 128)    0           conv5_10_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_10_x2 (Conv2D)            (None, 7, 7, 32)     36864       relu5_10_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_167 (Concatenate)   (None, 7, 7, 1728)   0           concatenate_166[0][0]
#                                                                  conv5_10_x2[0][0]
# __________________________________________________________________________________________________
# conv5_11_x1_bn (BatchNormalizat (None, 7, 7, 1728)   6912        concatenate_167[0][0]
# __________________________________________________________________________________________________
# conv5_11_x1_scale (Scale)       (None, 7, 7, 1728)   3456        conv5_11_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_11_x1 (Activation)        (None, 7, 7, 1728)   0           conv5_11_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_11_x1 (Conv2D)            (None, 7, 7, 128)    221184      relu5_11_x1[0][0]
# __________________________________________________________________________________________________
# conv5_11_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_11_x1[0][0]
# __________________________________________________________________________________________________
# conv5_11_x2_scale (Scale)       (None, 7, 7, 128)    256         conv5_11_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_11_x2 (Activation)        (None, 7, 7, 128)    0           conv5_11_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_11_x2 (Conv2D)            (None, 7, 7, 32)     36864       relu5_11_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_168 (Concatenate)   (None, 7, 7, 1760)   0           concatenate_167[0][0]
#                                                                  conv5_11_x2[0][0]
# __________________________________________________________________________________________________
# conv5_12_x1_bn (BatchNormalizat (None, 7, 7, 1760)   7040        concatenate_168[0][0]
# __________________________________________________________________________________________________
# conv5_12_x1_scale (Scale)       (None, 7, 7, 1760)   3520        conv5_12_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_12_x1 (Activation)        (None, 7, 7, 1760)   0           conv5_12_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_12_x1 (Conv2D)            (None, 7, 7, 128)    225280      relu5_12_x1[0][0]
# __________________________________________________________________________________________________
# conv5_12_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_12_x1[0][0]
# __________________________________________________________________________________________________
# conv5_12_x2_scale (Scale)       (None, 7, 7, 128)    256         conv5_12_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_12_x2 (Activation)        (None, 7, 7, 128)    0           conv5_12_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_12_x2 (Conv2D)            (None, 7, 7, 32)     36864       relu5_12_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_169 (Concatenate)   (None, 7, 7, 1792)   0           concatenate_168[0][0]
#                                                                  conv5_12_x2[0][0]
# __________________________________________________________________________________________________
# conv5_13_x1_bn (BatchNormalizat (None, 7, 7, 1792)   7168        concatenate_169[0][0]
# __________________________________________________________________________________________________
# conv5_13_x1_scale (Scale)       (None, 7, 7, 1792)   3584        conv5_13_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_13_x1 (Activation)        (None, 7, 7, 1792)   0           conv5_13_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_13_x1 (Conv2D)            (None, 7, 7, 128)    229376      relu5_13_x1[0][0]
# __________________________________________________________________________________________________
# conv5_13_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_13_x1[0][0]
# __________________________________________________________________________________________________
# conv5_13_x2_scale (Scale)       (None, 7, 7, 128)    256         conv5_13_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_13_x2 (Activation)        (None, 7, 7, 128)    0           conv5_13_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_13_x2 (Conv2D)            (None, 7, 7, 32)     36864       relu5_13_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_170 (Concatenate)   (None, 7, 7, 1824)   0           concatenate_169[0][0]
#                                                                  conv5_13_x2[0][0]
# __________________________________________________________________________________________________
# conv5_14_x1_bn (BatchNormalizat (None, 7, 7, 1824)   7296        concatenate_170[0][0]
# __________________________________________________________________________________________________
# conv5_14_x1_scale (Scale)       (None, 7, 7, 1824)   3648        conv5_14_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_14_x1 (Activation)        (None, 7, 7, 1824)   0           conv5_14_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_14_x1 (Conv2D)            (None, 7, 7, 128)    233472      relu5_14_x1[0][0]
# __________________________________________________________________________________________________
# conv5_14_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_14_x1[0][0]
# __________________________________________________________________________________________________
# conv5_14_x2_scale (Scale)       (None, 7, 7, 128)    256         conv5_14_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_14_x2 (Activation)        (None, 7, 7, 128)    0           conv5_14_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_14_x2 (Conv2D)            (None, 7, 7, 32)     36864       relu5_14_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_171 (Concatenate)   (None, 7, 7, 1856)   0           concatenate_170[0][0]
#                                                                  conv5_14_x2[0][0]
# __________________________________________________________________________________________________
# conv5_15_x1_bn (BatchNormalizat (None, 7, 7, 1856)   7424        concatenate_171[0][0]
# __________________________________________________________________________________________________
# conv5_15_x1_scale (Scale)       (None, 7, 7, 1856)   3712        conv5_15_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_15_x1 (Activation)        (None, 7, 7, 1856)   0           conv5_15_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_15_x1 (Conv2D)            (None, 7, 7, 128)    237568      relu5_15_x1[0][0]
# __________________________________________________________________________________________________
# conv5_15_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_15_x1[0][0]
# __________________________________________________________________________________________________
# conv5_15_x2_scale (Scale)       (None, 7, 7, 128)    256         conv5_15_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_15_x2 (Activation)        (None, 7, 7, 128)    0           conv5_15_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_15_x2 (Conv2D)            (None, 7, 7, 32)     36864       relu5_15_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_172 (Concatenate)   (None, 7, 7, 1888)   0           concatenate_171[0][0]
#                                                                  conv5_15_x2[0][0]
# __________________________________________________________________________________________________
# conv5_16_x1_bn (BatchNormalizat (None, 7, 7, 1888)   7552        concatenate_172[0][0]
# __________________________________________________________________________________________________
# conv5_16_x1_scale (Scale)       (None, 7, 7, 1888)   3776        conv5_16_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_16_x1 (Activation)        (None, 7, 7, 1888)   0           conv5_16_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_16_x1 (Conv2D)            (None, 7, 7, 128)    241664      relu5_16_x1[0][0]
# __________________________________________________________________________________________________
# conv5_16_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_16_x1[0][0]
# __________________________________________________________________________________________________
# conv5_16_x2_scale (Scale)       (None, 7, 7, 128)    256         conv5_16_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_16_x2 (Activation)        (None, 7, 7, 128)    0           conv5_16_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_16_x2 (Conv2D)            (None, 7, 7, 32)     36864       relu5_16_x2[0][0]
# __________________________________________________________________________________________________
# concatenate_173 (Concatenate)   (None, 7, 7, 1920)   0           concatenate_172[0][0]
#                                                                  conv5_16_x2[0][0]
# __________________________________________________________________________________________________
# conv5_blk_bn (BatchNormalizatio (None, 7, 7, 1920)   7680        concatenate_173[0][0]
# __________________________________________________________________________________________________
# conv5_blk_scale (Scale)         (None, 7, 7, 1920)   3840        conv5_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu5_blk (Activation)          (None, 7, 7, 1920)   0           conv5_blk_scale[0][0]
# __________________________________________________________________________________________________
# pool5 (GlobalAveragePooling2D)  (None, 1920)         0           relu5_blk[0][0]
# __________________________________________________________________________________________________
# fc6 (Dense)                     (None, 1000)         1921000     pool5[0][0]
# __________________________________________________________________________________________________
# prob (Activation)               (None, 1000)         0           fc6[0][0]
# ==================================================================================================
# Total params: 14,181,864
# Trainable params: 14,045,224
# Non-trainable params: 136,640
# __________________________________________________________________________________________________

# %% [markdown]
# #This code cell holds the DenseNet model imported from the keras.applications library

# %%
INPUT_SHAPE = (32, 128, 1) # (img_rows, img_cols, img_channel)

REG = 0.0001 
from keras.layers import LSTM, Reshape, Input, Conv2D, MaxPool2D, Bidirectional
from keras.applications import VGG16, ResNet50, MobileNet, Xception, DenseNet121, ResNet152V2

def make_model():
  #base_model = ResNet50(include_top=False, weights=None, input_tensor=None, input_shape=INPUT_SHAPE)
  #base_model = ResNet152V2(include_top=False, weights=None, input_tensor=None, input_shape=INPUT_SHAPE)
  base_model = DenseNet121(include_top=False, weights=None, input_tensor=None, input_shape=INPUT_SHAPE)

  #model = Model(base_model.inputs, base_model.outputs)
  base_model.summary()
  # x = base_model.layers[51].output
  # model = Model(base_model.inputs, x)
  # model.summary()

make_model()
